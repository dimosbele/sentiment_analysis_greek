# %%
import pandas as pd

# %%
df = pd.read_pickle('df_final.pkl')

# %%
df.head()
# Out:
#                                                 Text  \
# 0  Επιχείρηση Βολευτική έδρα!  Βασίλης Οικονόμου:...
# 1  Κ ά β ο ς: Ψηφοδέλτιο ΣΥΡΙΖΑ Κορινθίας - Πού π...
# 2  @Dora_Bakoyannis Αυτο-καρφώνεσαι όταν αναρωτιέ...
# 3  Κόμμα «σκαντζόχοιρος»: «Σφαγή» πασοκογενών από...
# 4  Και γαμώ και την Νέα Δημοκρατία γιατί ειμαι πο...
#
#                                            Text_only  \
# 0  Επιχείρηση Βολευτική έδρα! Βασίλης Οικονόμου: ...
# 1  Κ ά β ο ς: Ψηφοδέλτιο ΣΥΡΙΖΑ Κορινθίας - Πού π...
# 2  Αυτο-καρφώνεσαι όταν αναρωτιέσαι ποιον ΠτΔ θα ...
# 3  Κόμμα «σκαντζόχοιρος»: «Σφαγή» πασοκογενών από...
# 4  Και γαμώ και την Νέα Δημοκρατία γιατί ειμαι πο...
#
#                                               Tokens  \
# 0  [ΕΠΙΧΕΙΡΗΣΗ, ΒΟΛΕΥΤΙΚΗ, ΕΔΡΑ, ΒΑΣΙΛΗΣ, ΟΙΚΟΝΟΜ...
# 1  [Κ, Α, Β, Ο, Σ, ΨΗΦΟΔΕΛΤΙΟ, ΣΥΡΙΖΑ, ΚΟΡΙΝΘΙΑΣ,...
# 2  [ΑΥΤΟ, ΚΑΡΦΩΝΕΣΑΙ, ΟΤΑΝ, ΑΝΑΡΩΤΙΕΣΑΙ, ΠΟΙΟΝ, Π...
# 3  [ΚΟΜΜΑ, ΣΚΑΝΤΖΟΧΟΙΡΟΣ, ΣΦΑΓΗ, ΠΑΣΟΚΟΓΕΝΩΝ, ΑΠΟ...
# ...

# %%
df.columns
# Out:
# Index(['Text', 'Text_only', 'Tokens', 'Tokens_stem', 'Bigrams2', 'N_exclam',
#        'has_url', 'N_hash', 'N_mentions', 'N_uppers', 'N_words', 'Sentiment',
#        'N_matches', 'Match_Terms', 'Sum_subj', 'Sum_positive', 'Sum_negative',
#        'Sum_anger', 'Sum_disgust', 'Sum_fear', 'Sum_happy', 'Sum_sad',
#        'Sum_surprise', 'N_Uni_Neg', 'Score_Uni_Neg', 'N_Uni_Pos',
#        'Score_Uni_Pos', 'N_Bi_Neg', 'Score_Bi_Neg', 'N_Bi_Pos', 'Score_Bi_Pos',
#        'Score_Uni', 'Score_Bi', 'N_verbs', 'N_adjs', 'N_nouns'],
#       dtype='object')
